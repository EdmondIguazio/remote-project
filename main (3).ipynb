# %%
import mlrun

# %%
project = mlrun.get_or_create_project("remote-project")
# Out:
# > 2025-08-18 13:14:47,344 [warning] Please add git branch or refs to the source e.g.: 'git://<url>/org/repo.git#<branch-name or refs/heads/..>'
# > 2025-08-18 13:14:47,531 [info] Project loaded successfully: {"project_name":"remote-project"}

# %%
project.run(name="workflow",
            watch=True,
            engine="remote")
# Out:
# > 2025-08-18 13:14:49,497 [info] Submitting remote workflow: {"project_name":"remote-project","schedule":null,"workflow_engine":"kfp"}
# <div>Pipeline running (id=0e1d7455-15d9-4383-bece-d164c5aa940b), <a href="https://mlrun-ui.default-tenant.app.cust-cs-il.iguazio-cd0.com/mlprojects/remote-project/jobs/monitor-workflows/workflow/0e1d7455-15d9-4383-bece-d164c5aa940b" target="_blank"><b>click here</b></a> to view the details in MLRun UI</div>
# > 2025-08-18 13:14:57,188 [info] Started run workflow remote-project-workflow with run id = '0e1d7455-15d9-4383-bece-d164c5aa940b' by remote engine
# > 2025-08-18 13:14:57,189 [info] Waiting for pipeline run completion: {"project":"remote-project","run_id":"0e1d7455-15d9-4383-bece-d164c5aa940b"}
# <h2>Run Results</h2><h3>[info] Workflow 0e1d7455-15d9-4383-bece-d164c5aa940b finished, state=Succeeded</h3><br>click the hyper links below to see detailed results<br><table border="1" class="dataframe">
#   <thead>
# ...
