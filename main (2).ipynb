# %%
import mlrun

# %%
project = mlrun.get_or_create_project("remote-project")
# Out:
# > 2025-08-18 12:57:53,929 [warning] Please add git branch or refs to the source e.g.: 'git://<url>/org/repo.git#<branch-name or refs/heads/..>'
# > 2025-08-18 12:57:54,102 [info] Project loaded successfully: {"project_name":"remote-project"}
